# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:114.0) Gecko/20100101 Firefox/114.0",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1"
}
webpage=requests.get('https://www.happychildschool.org/',headers=headers).text

# %%
Soup=BeautifulSoup(webpage, 'lxml')

# %%
print(Soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <!-- Meta Tags -->
#   <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="HAPPY CHILD SR. SEC. SCHOOL" name="description"/>
#   <meta content="HAPPY CHILD SR. SEC. SCHOOL" name="keywords"/>
#   <!-- Page Title -->
#   <title>
#    HAPPY CHILD SR. SEC. SCHOOL
#   </title>
#   <!-- Favicon and Touch Icons -->
#   <link href="images/favicon.png" rel="shortcut icon" type="image/png"/>
#   <link href="images/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="images/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="images/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="images/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <!-- Stylesheet -->
# ...

# %%
Soup.find_all('head')[0].text
# Out:
# '\n\n\n\n\n\n\nHAPPY CHILD SR. SEC. SCHOOL\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'

# %%
Soup.find_all('h2')
# Out:
# [<h2 class="text-theme-colored" style="margin-top: 0px;">Welcome to Our School
#
#  			  <img src="images/about-us.jpg" style="float:left; padding:0px 10px 10px 0px; width:50%"/>
#  </h2>,
#  <h2 class="mt-0 text-uppercase font-28 line-bottom line-height-1">Our <span class="text-theme-color-2 font-weight-400">Instructors</span></h2>,
#  <h2 class="text-uppercase text-theme-colored font line-bottom line-height-1 mt-0 mb-0">Our <span class="text-theme-color-2 font-weight-400">Features</span></h2>,
#  <h2 class="text-uppercase text-theme-colored title line-bottom line-height-1 mt-0">Contact <span class="text-theme-color-2 font-weight-400">Us</span></h2>,
#  <h2 class="animate-number text-white mt-0 font-38 font-weight-500" data-animation-duration="2000" data-value="5248" style="display:none">0</h2>,
#  <h2 class="animate-number text-white mt-0 font-38 font-weight-500" data-animation-duration="2000" data-value="675" style="display:none">0</h2>,
# ...

# %%
for i in Soup.find_all('h2'):
    print(i.text)
# Out:
# Welcome to Our School
#
#
#
# Our Instructors
# Our Features
# Contact Us
# 0
# 0
# 0
# Our Gallery

# %%
Soup.find_all('a')
# Out:
# [<a class="text-white" href="#" style="color:#fff; font-weight:bold; margin-right: 10px; font-size: 16px;"><i class="fa fa-phone text-white" style="font-weight:bold"></i> +91-8950809781</a>,
#  <a href="mailto:hcgisonipat@gmail.com" style="color:#fff; font-weight:bold; line-height: 36px;     margin-right: 17px; font-size: 16px;">hcgisonipat@gmail.com</a>,
#  <a href="https://www.facebook.com/happychildsnp"><i class="fa fa-facebook text-white"></i></a>,
#  <a href="https://www.youtube.com/@happychildsr.sec.school517"><i class="fa fa-youtube text-white"></i></a>,
#  <a class="menuzord-brand pull-left flip xs-pull-center mb-15" href="javascript:void(0)" style="margin: 4px 0px 4px 0px !important;">
#  <img alt="" src="images/logo-wide.png"/>
#  </a>,
#  <a class="font-12 text-gray text-uppercase" href="#">Call us today!</a>,
#  <a class="font-12 text-gray text-uppercase" href="#">Timing</a>,
#  <a href="index.php">Home</a>,
#  <a href="#">About us</a>,
# ...

# %%
company=Soup.find_all('i',class_='fa fa-laptop')

# %%
len(company)
# Out:
# 1

# %%
# name=[]
# rating=[]
# for i in company:
#     name.apppend(i.find('a'))
#     rating.append(i.find_all('a',class_='enter the class name')[0].text.string())
